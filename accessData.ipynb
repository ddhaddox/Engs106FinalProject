# %%
import zipfile
import pandas as pd

# %% [markdown]
# Not really relevent anymore, just had to split the training file to make it small enough to upload to github
#
# Then I had unzip some stuff, then re-zip

# %%
# # Open the zip file
# zip_path = "optiver-trading-at-the-close.zip"
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     # List all file names in the zip archive
#     file_list = zip_ref.namelist()
    
#     # Iterate through each file
#     for file_name in file_list:
#         print(file_name)
# Out:
# example_test_files/revealed_targets.csv
# example_test_files/sample_submission.csv
# example_test_files/test.csv
# optiver2023/__init__.py
# optiver2023/competition.cpython-310-x86_64-linux-gnu.so
# public_timeseries_testing_util.py
# train.csv

# %%
# training_file = "Final Project/optiver-trading-at-the-close/train.csv"
# df = pd.read_csv("optiver-trading-at-the-close/train.csv")

# %%
# split_size = len(df) // 3

# # Create three separate DataFrames
# df_part_1 = df.iloc[:split_size]
# df_part_2 = df.iloc[split_size:2*split_size]
# df_part_3 = df.iloc[2*split_size:]

# # Save each part as a separate CSV
# df_part_1.to_csv("train_part_1.csv", index=False)
# df_part_2.to_csv("train_part_2.csv", index=False)
# df_part_3.to_csv("train_part_3.csv", index=False)

# %%
## How to read the training data now
file_path = "optiver_training_data/train_part_1.csv.zip"
df_1 = pd.read_csv(file_path, compression='zip')

file_path = "optiver_training_data/train_part_2.csv.zip"
df_2 = pd.read_csv(file_path, compression='zip')

file_path = "optiver_training_data/train_part_3.csv.zip"
df_3 = pd.read_csv(file_path, compression='zip')

# %%
df = pd.concat([df_1, df_2, df_3], ignore_index=True)
df.head()
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0        0                  0      3180602.69
# 1         1        0                  0       166603.91
# 2         2        0                  0       302879.87
# 3         3        0                  0     11917682.27
# 4         4        0                  0       447549.96
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.999812   13380276.64        NaN
# 1                       -1         0.999896    1642214.25        NaN
# 2                       -1         0.999561    1819368.03        NaN
# 3                       -1         1.000171   18389745.62        NaN
# 4                       -1         0.999532   17860614.95        NaN
#
#    near_price  bid_price  bid_size  ask_price   ask_size  wap    target  \
# 0         NaN   0.999812  60651.50   1.000026    8493.03  1.0 -3.029704
# ...
