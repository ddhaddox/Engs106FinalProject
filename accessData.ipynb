# %%
import pandas as pd

# %% [markdown]
# # How to think about the Data
#
# Note, we will likely just use the training data + potentially the testing data too, but ignore all things API related, although I include how to access them here

# %% [markdown]
# ## Grabbing the Training Data

# %%
## How to read the training data now
file_path = "optiver_training_data/train_part_1.csv.zip"
df_1 = pd.read_csv(file_path, compression='zip')

file_path = "optiver_training_data/train_part_2.csv.zip"
df_2 = pd.read_csv(file_path, compression='zip')

file_path = "optiver_training_data/train_part_3.csv.zip"
df_3 = pd.read_csv(file_path, compression='zip')

# %%
df = pd.concat([df_1, df_2, df_3], ignore_index=True)
df.head()
# Out:
#    stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0         0        0                  0      3180602.69
# 1         1        0                  0       166603.91
# 2         2        0                  0       302879.87
# 3         3        0                  0     11917682.27
# 4         4        0                  0       447549.96
#
#    imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                        1         0.999812   13380276.64        NaN
# 1                       -1         0.999896    1642214.25        NaN
# 2                       -1         0.999561    1819368.03        NaN
# 3                       -1         1.000171   18389745.62        NaN
# 4                       -1         0.999532   17860614.95        NaN
#
#    near_price  bid_price  bid_size  ask_price   ask_size  wap    target  \
# 0         NaN   0.999812  60651.50   1.000026    8493.03  1.0 -3.029704
# ...

# %%
df["stock_id"].nunique()
# Out:
# 200

# %%
df["date_id"].nunique()
# Out:
# 481

# %%
df["time_id"].nunique()
# Out:
# 26455

# %%
len(df)
# Out:
# 5237980

# %%
df.isna().sum()
# Out:
# stock_id                         0
# date_id                          0
# seconds_in_bucket                0
# imbalance_size                 220
# imbalance_buy_sell_flag          0
# reference_price                220
# matched_size                   220
# far_price                  2894342
# near_price                 2857180
# bid_price                      220
# bid_size                         0
# ask_price                      220
# ask_size                         0
# wap                            220
# target                          88
# time_id                          0
# row_id                           0
# dtype: int64

# %%
# False means time_id and stock_id are primary keys of the df
df.duplicated(subset=['time_id', 'stock_id']).any()
# Out:
# np.False_

# %% [markdown]
# ## Extra Folder: optiver-trading-at-the-close/example_test_files
#
# Data intended to illustrate how the API functions. Includes the same files and columns delivered by the API. The first three date ids are repeats of the last three date ids in the train set, to enable an illustration of how the API functions.

# %%
revealed_targets_csv = "optiver-trading-at-the-close/example_test_files/revealed_targets.csv"
revealed_targets_df = pd.read_csv(revealed_targets_csv)
revealed_targets_df

# When the first time_id for each date (i.e. when seconds_in_bucket equals zero) 
# the API will serve a dataframe providing the true target values for the entire 
# previous date. All other rows contain null values for the columns of interest.
# Out:
#        stock_id  date_id  seconds_in_bucket  time_id  revealed_target  \
# 0           0.0      478                  0    26290        -2.310276
# 1           1.0      478                  0    26290       -12.850165
# 2           2.0      478                  0    26290        -0.439882
# 3           3.0      478                  0    26290         7.259846
# 4           4.0      478                  0    26290         4.780292
# ...         ...      ...                ...      ...              ...
# 33157       NaN      480                500    26450              NaN
# 33158       NaN      480                510    26451              NaN
# 33159       NaN      480                520    26452              NaN
# 33160       NaN      480                530    26453              NaN
# 33161       NaN      480                540    26454              NaN
#
#        revealed_date_id  revealed_time_id
# 0                 477.0           26235.0
# ...

# %%
revealed_targets_df.isna().sum()
# Out:
# stock_id             162
# date_id                0
# seconds_in_bucket      0
# time_id                0
# revealed_target      162
# revealed_date_id     162
# revealed_time_id     162
# dtype: int64

# %%
# A valid sample submission, delivered by the API.
sample_submission_csv = "optiver-trading-at-the-close/example_test_files/sample_submission.csv"
sample_submission_df = pd.read_csv(sample_submission_csv)
sample_submission_df
# Out:
#        time_id       row_id  target
# 0        26290      478_0_0       0
# 1        26290      478_0_1       0
# 2        26290      478_0_2       0
# 3        26290      478_0_3       0
# 4        26290      478_0_4       0
# ...        ...          ...     ...
# 32995    26454  480_540_195       0
# 32996    26454  480_540_196       0
# 32997    26454  480_540_197       0
# 32998    26454  480_540_198       0
# 32999    26454  480_540_199       0
#
# [33000 rows x 3 columns]

# %%
test_csv = "optiver-trading-at-the-close/example_test_files/test.csv"
test_df = pd.read_csv(test_csv)
test_df
# Out:
#        stock_id  date_id  seconds_in_bucket  imbalance_size  \
# 0             0      478                  0      3753451.43
# 1             1      478                  0       985977.11
# 2             2      478                  0       599128.74
# 3             3      478                  0      2872317.54
# 4             4      478                  0       740059.14
# ...         ...      ...                ...             ...
# 32995       195      480                540      2440722.89
# 32996       196      480                540       349510.47
# 32997       197      480                540            0.00
# 32998       198      480                540      1000898.84
# 32999       199      480                540      1884285.71
#
#        imbalance_buy_sell_flag  reference_price  matched_size  far_price  \
# 0                           -1         0.999875   11548975.43        NaN
# 1                           -1         1.000245    3850033.97        NaN
# ...

# %%
test_df.isna().sum()
# Out:
# stock_id                       0
# date_id                        0
# seconds_in_bucket              0
# imbalance_size                 0
# imbalance_buy_sell_flag        0
# reference_price                0
# matched_size                   0
# far_price                  18229
# near_price                 18000
# bid_price                      0
# bid_size                       0
# ask_price                      0
# ask_size                       0
# wap                            0
# time_id                        0
# row_id                         0
# currently_scored               0
# dtype: int64

# %% [markdown]
# ### Extra Folder: optiver-trading-at-the-close/optiver2023
#
# Files that enable the API. Expect the API to deliver all rows in under five minutes and to reserve less than 0.5 GB of memory. The first three date ids delivered by the API are repeats of the last three date ids in the train set, to better illustrate how the API functions. You must make predictions for those dates in order to advance the API but those predictions are not scored.

# %% [markdown]
# Extra File: public_timeseries_testing_util.py
#
# - An optional file intended to make it easier to run custom offline API tests. See the script's docstring for details. You will need to edit this file before using it.
